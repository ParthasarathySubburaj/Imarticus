# %% [markdown]
# # Numpy

# %%
import numpy as np

# %%
A = np.array([2,3,6,8])  ## np has a method called array which takes [numbers] and returns a object

# %%
print(A)
# Out:
# [2 3 6 8]

# %%
A*2
# Out:
# array([ 4,  6, 12, 16])

# %%
A**2
# Out:
# array([ 4,  9, 36, 64], dtype=int32)

# %%
np.sum(A)
# Out:
# 19

# %%
np.median(A)
# Out:
# 4.5

# %%
B = np.ones(4)
B
# Out:
# array([1., 1., 1., 1.])

# %%
C = np.arange(5)
C
# Out:
# array([0, 1, 2, 3, 4])

# %%
A = np.array([[2,3],[-1,-2]])
A
# Out:
# array([[ 2,  3],
#        [-1, -2]])

# %%
B = np.array([[3,-1],[0,2]])
B
# Out:
# array([[ 3, -1],
#        [ 0,  2]])

# %%
A*B
# Out:
# array([[ 6, -3],
#        [ 0, -4]])

# %%
A.dot(B)

# %%
sum(A.sum(axis=1))
# Out:
# 2

# %%
A = np.eye(3)
A
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
A.ravel()
# Out:
# array([1., 0., 0., 0., 1., 0., 0., 0., 1.])

# %%
np.random.seed(10)
np.random.randint(1,6,10)
# Out:
# array([2, 5, 1, 2, 4, 5, 2, 1, 2, 3])

# %%
np.random.uniform(60,100,10)
# Out:
# array([98.13573385, 60.15793065, 80.48769054, 92.50483847, 84.50104267,
#        88.8702127 , 71.67504273, 96.7109649 , 88.58303134, 81.70177472])

# %%
np.random.normal(2,1,5)
# Out:
# array([1.64969879, 1.0103504 , 1.36574583, 3.89876222, 3.99652279])

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
data = pd.read_csv("./Data/SalesJan2009.csv")

# %%
data
# Out:
#      Transaction_date   Product Price Payment_Type               Name  \
# 0    01-02-2009 06:17  Product1  1200   Mastercard           carolina
# 1    01-02-2009 04:53  Product1  1200         Visa             Betina
# 2    01-02-2009 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3    01-03-2009 14:44  Product1  1200         Visa              Gouya
# 4    01-04-2009 12:56  Product2  3600         Visa            Gerd W
# 5    01-04-2009 13:19  Product1  1200         Visa           LAURENCE
# 6    01-04-2009 20:11  Product1  1200   Mastercard              Fleur
# 7    01-02-2009 20:09  Product1  1200   Mastercard               adam
# 8    01-04-2009 13:17  Product1  1200   Mastercard    Renee Elisabeth
# 9    01-04-2009 14:11  Product1  1200         Visa              Aidan
# 10   01-05-2009 02:42  Product1  1200       Diners              Stacy
# 11   01-05-2009 05:39  Product1  1200         Amex              Heidi
# ...

# %%
data.head()
# Out:
#    Transaction_date   Product Price Payment_Type               Name  \
# 0  01-02-2009 06:17  Product1  1200   Mastercard           carolina
# 1  01-02-2009 04:53  Product1  1200         Visa             Betina
# 2  01-02-2009 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3  01-03-2009 14:44  Product1  1200         Visa              Gouya
# 4  01-04-2009 12:56  Product2  3600         Visa            Gerd W
#
#                            City     State         Country   Account_Created  \
# 0                      Basildon   England  United Kingdom  01-02-2009 06:00
# 1  Parkville                           MO   United States  01-02-2009 04:42
# 2  Astoria                             OR   United States  01-01-2009 16:21
# 3                        Echuca  Victoria       Australia     9/25/05 21:13
# 4  Cahaba Heights                      AL   United States    11/15/08 15:47
#
#          Last_Login   Latitude   Longitude
# 0  01-02-2009 06:08  51.500000   -1.116667
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (998, 12)

# %%
data.columns
# Out:
# Index(['Transaction_date', 'Product', 'Price', 'Payment_Type', 'Name', 'City',
#        'State', 'Country', 'Account_Created', 'Last_Login', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
data["Name"]
# Out:
# 0               carolina
# 1                 Betina
# 2      Federica e Andrea
# 3                  Gouya
# 4                Gerd W
# 5               LAURENCE
# 6                  Fleur
# 7                   adam
# 8        Renee Elisabeth
# 9                  Aidan
# 10                 Stacy
# 11                 Heidi
# 12                 Sean
# 13               Georgia
# 14               Richard
# 15                Leanne
# 16                 Janet
# 17               barbara
# 18                Sabine
# 19                  Hani
# 20                Jeremy
# 21                 Janis
# 22                Nicola
# 23                asuman
# 24                  Lena
# 25                  Lisa
# 26         Bryan Kerrene
# 27                 chris
# 28                Maxine
# 29                Family
#              ...
# 968                clara
# 969                Selma
# 970        Doug and Tina
# 971               Lauren
# 972                  Jen
# 973               gladys
# ...

# %%
data["Country"]
# Out:
# 0      United Kingdom
# 1       United States
# 2       United States
# 3           Australia
# 4       United States
# 5       United States
# 6       United States
# 7       United States
# 8              Israel
# 9              France
# 10      United States
# 11        Netherlands
# 12      United States
# 13      United States
# 14      United States
# 15            Ireland
# 16             Canada
# 17              India
# 18     United Kingdom
# 19      United States
# 20     United Kingdom
# 21            Ireland
# 22       South Africa
# 23      United States
# 24            Finland
# 25      United States
# 26      United States
# 27     United Kingdom
# 28      United States
# 29      United States
#             ...
# 968         Australia
# 969     United States
# 970     United States
# 971    Czech Republic
# 972    United Kingdom
# 973    United Kingdom
# 974           Romania
# 975             Malta
# 976     United States
# 977    United Kingdom
# ...

# %%
np.unique(data["Country"])
# Out:
# array(['Argentina', 'Australia', 'Austria', 'Bahrain', 'Belgium',
#        'Bermuda', 'Brazil', 'Bulgaria', 'Canada', 'Cayman Isls', 'China',
#        'Costa Rica', 'Czech Republic', 'Denmark', 'Dominican Republic',
#        'Finland', 'France', 'Germany', 'Greece', 'Guatemala', 'Hong Kong',
#        'Hungary', 'Iceland', 'India', 'Ireland', 'Israel', 'Italy',
#        'Japan', 'Jersey', 'Kuwait', 'Latvia', 'Luxembourg', 'Malaysia',
#        'Malta', 'Mauritius', 'Moldova', 'Monaco', 'Netherlands',
#        'New Zealand', 'Norway', 'Philippines', 'Poland', 'Romania',
#        'Russia', 'South Africa', 'South Korea', 'Spain', 'Sweden',
#        'Switzerland', 'Thailand', 'The Bahamas', 'Turkey', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States'],
#       dtype=object)

# %%
data.head()
# Out:
#    Transaction_date   Product Price Payment_Type               Name  \
# 0  01-02-2009 06:17  Product1  1200   Mastercard           carolina
# 1  01-02-2009 04:53  Product1  1200         Visa             Betina
# 2  01-02-2009 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3  01-03-2009 14:44  Product1  1200         Visa              Gouya
# 4  01-04-2009 12:56  Product2  3600         Visa            Gerd W
#
#                            City     State         Country   Account_Created  \
# 0                      Basildon   England  United Kingdom  01-02-2009 06:00
# 1  Parkville                           MO   United States  01-02-2009 04:42
# 2  Astoria                             OR   United States  01-01-2009 16:21
# 3                        Echuca  Victoria       Australia     9/25/05 21:13
# 4  Cahaba Heights                      AL   United States    11/15/08 15:47
#
#          Last_Login   Latitude   Longitude
# 0  01-02-2009 06:08  51.500000   -1.116667
# ...

# %%
data.loc[1]
# Out:
# Transaction_date                01-02-2009 04:53
# Product                                 Product1
# Price                                       1200
# Payment_Type                                Visa
# Name                                      Betina
# City                Parkville
# State                                         MO
# Country                            United States
# Account_Created                 01-02-2009 04:42
# Last_Login                      01-02-2009 07:49
# Latitude                                  39.195
# Longitude                               -94.6819
# Name: 1, dtype: object

# %%
data.loc[2:5]
# Out:
#    Transaction_date   Product Price Payment_Type               Name  \
# 2  01-02-2009 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3  01-03-2009 14:44  Product1  1200         Visa              Gouya
# 4  01-04-2009 12:56  Product2  3600         Visa            Gerd W
# 5  01-04-2009 13:19  Product1  1200         Visa           LAURENCE
#
#                            City     State        Country   Account_Created  \
# 2  Astoria                             OR  United States  01-01-2009 16:21
# 3                        Echuca  Victoria      Australia     9/25/05 21:13
# 4  Cahaba Heights                      AL  United States    11/15/08 15:47
# 5  Mickleton                           NJ  United States     9/24/08 15:19
#
#          Last_Login   Latitude  Longitude
# 2  01-03-2009 12:32  46.188060 -123.83000
# 3  01-03-2009 14:22 -36.133333  144.75000
# 4  01-04-2009 12:45  33.520560  -86.80250
# 5  01-04-2009 13:04  39.790000  -75.23806

# %%
data.loc[2:5,["Name", "City"]]
# Out:
#                 Name                          City
# 2  Federica e Andrea  Astoria
# 3              Gouya                        Echuca
# 4            Gerd W   Cahaba Heights
# 5           LAURENCE  Mickleton

# %%
data.loc[500:,["Name", "City"]]
# Out:
#               Name                          City
# 500        Patrick  Birmingham
# 501          Heidi  St Augustine
# 502            Tom  Salt Lake City
# 503        Justine  Seattle
# 504         isabel                          Ruti
# 505          scott  Rogers
# 506         Fatima  Rogers
# 507           Judy                 Dun Laoghaire
# 508          Glenn                         Perth
# 509      Family in                        London
# 510         Lauren                         Gries
# 511        Michael              Pietermaritzburg
# 512           Jodi                Sutton Valence
# 513         simone                        Lyngby
# 514          Sonja  Alpine
# 515          Shane                        Zurich
# 516           Ruth                     Saskatoon
# 517           Cleo  Pacific Palisades
# 518         Benoit              Fort Saint James
# 519         Claire                       Versoix
# 520         Claire  Trumansburg
# 521        Lindsey  Kennett Square
# ...

# %%
set(("a","e","i"))
# Out:
# {'a', 'e', 'i'}

# %%
data.loc[:10,["Name", "City"]]
# Out:
#                  Name                          City
# 0            carolina                      Basildon
# 1              Betina  Parkville
# 2   Federica e Andrea  Astoria
# 3               Gouya                        Echuca
# 4             Gerd W   Cahaba Heights
# 5            LAURENCE  Mickleton
# 6               Fleur  Peoria
# 7                adam  Martin
# 8     Renee Elisabeth                      Tel Aviv
# 9               Aidan                        Chatou
# 10              Stacy  New York

# %%
data
# Out:
#      Transaction_date   Product Price Payment_Type               Name  \
# 0    01-02-2009 06:17  Product1  1200   Mastercard           carolina
# 1    01-02-2009 04:53  Product1  1200         Visa             Betina
# 2    01-02-2009 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3    01-03-2009 14:44  Product1  1200         Visa              Gouya
# 4    01-04-2009 12:56  Product2  3600         Visa            Gerd W
# 5    01-04-2009 13:19  Product1  1200         Visa           LAURENCE
# 6    01-04-2009 20:11  Product1  1200   Mastercard              Fleur
# 7    01-02-2009 20:09  Product1  1200   Mastercard               adam
# 8    01-04-2009 13:17  Product1  1200   Mastercard    Renee Elisabeth
# 9    01-04-2009 14:11  Product1  1200         Visa              Aidan
# 10   01-05-2009 02:42  Product1  1200       Diners              Stacy
# 11   01-05-2009 05:39  Product1  1200         Amex              Heidi
# ...

# %%
data_USA = data[data["Country"]=="United States"]

# %%
data_USA
# Out:
#      Transaction_date   Product Price Payment_Type                  Name  \
# 1    01-02-2009 04:53  Product1  1200         Visa                Betina
# 2    01-02-2009 13:08  Product1  1200   Mastercard     Federica e Andrea
# 4    01-04-2009 12:56  Product2  3600         Visa               Gerd W
# 5    01-04-2009 13:19  Product1  1200         Visa              LAURENCE
# 6    01-04-2009 20:11  Product1  1200   Mastercard                 Fleur
# 7    01-02-2009 20:09  Product1  1200   Mastercard                  adam
# 10   01-05-2009 02:42  Product1  1200       Diners                 Stacy
# 12   01-02-2009 09:16  Product1  1200   Mastercard                 Sean
# 13   01-05-2009 10:08  Product1  1200         Visa               Georgia
# 14   01-02-2009 14:18  Product1  1200         Visa               Richard
# 19   01-02-2009 07:35  Product1  1200       Diners                  Hani
# 23   01-06-2009 07:18  Product1  1200         Visa                asuman
# ...

# %%
data_anne = data[data["Name"]=="anne"]

# %%
data_anne
# Out:
#      Transaction_date   Product Price Payment_Type  Name         City  \
# 100  01-08-2009 07:26  Product1  1200   Mastercard  anne  Bournemouth
#
#        State         Country Account_Created    Last_Login   Latitude  \
# 100  England  United Kingdom   1/25/08 15:46  1/15/09 1:36  50.716667
#
#      Longitude
# 100  -1.883333

# %%
data_USA_Visa = data[(data["Country"]=="United States") & (data["Payment_Type"]=="Visa")]

# %%
data_USA_Visa.shape
# Out:
# (226, 12)

# %%
data["discount"] = 0.5

# %%
data
# Out:
#      Transaction_date   Product Price Payment_Type               Name  \
# 0    01-02-2009 06:17  Product1  1200   Mastercard           carolina
# 1    01-02-2009 04:53  Product1  1200         Visa             Betina
# 2    01-02-2009 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3    01-03-2009 14:44  Product1  1200         Visa              Gouya
# 4    01-04-2009 12:56  Product2  3600         Visa            Gerd W
# 5    01-04-2009 13:19  Product1  1200         Visa           LAURENCE
# 6    01-04-2009 20:11  Product1  1200   Mastercard              Fleur
# 7    01-02-2009 20:09  Product1  1200   Mastercard               adam
# 8    01-04-2009 13:17  Product1  1200   Mastercard    Renee Elisabeth
# 9    01-04-2009 14:11  Product1  1200         Visa              Aidan
# 10   01-05-2009 02:42  Product1  1200       Diners              Stacy
# 11   01-05-2009 05:39  Product1  1200         Amex              Heidi
# ...

# %%
data["New_price"] = data["Price"]*data["discount"]

# %%
def convert (a):
    return float(a)

# %%
data["Price"].apply(convert)

# %%
A ="10,000"

# %%
float(A.replace(",",""))
# Out:
# 10000.0

# %%
A = "13,000"
float(A)

# %%
A = A.replace(",","")

# %%
float(A)

# %%
def convert (a):
    c =a.replace(",","")
    return float(c)

# %%
data["Price"] = data["Price"].apply(convert)

# %%
data["Price"] = data["Price"].apply(lambda x: float(x = x.replace(",","")))

# %%
data["New_price"] = data["Price"]*data["discount"]

# %%
data
# Out:
#      Transaction_date   Product   Price Payment_Type               Name  \
# 0    01-02-2009 06:17  Product1  1200.0   Mastercard           carolina
# 1    01-02-2009 04:53  Product1  1200.0         Visa             Betina
# 2    01-02-2009 13:08  Product1  1200.0   Mastercard  Federica e Andrea
# 3    01-03-2009 14:44  Product1  1200.0         Visa              Gouya
# 4    01-04-2009 12:56  Product2  3600.0         Visa            Gerd W
# 5    01-04-2009 13:19  Product1  1200.0         Visa           LAURENCE
# 6    01-04-2009 20:11  Product1  1200.0   Mastercard              Fleur
# 7    01-02-2009 20:09  Product1  1200.0   Mastercard               adam
# 8    01-04-2009 13:17  Product1  1200.0   Mastercard    Renee Elisabeth
# 9    01-04-2009 14:11  Product1  1200.0         Visa              Aidan
# 10   01-05-2009 02:42  Product1  1200.0       Diners              Stacy
# 11   01-05-2009 05:39  Product1  1200.0         Amex              Heidi
# ...

# %%
data = data.drop(["Last_Login"],axis=1)

# %%
data_1 = data.loc[:,["Transaction_date","Product","Price","Payment_Type", "Name","Account_Created"]]

# %%
data_1.to_csv("data_subset_1.csv")

# %%
data_2 = data.drop(["Transaction_date","Product","Price","Payment_Type", "Name","Account_Created"],axis=1)

# %%
data_2.to_csv("data_subset_2.csv")

# %%
d1 = {'Customer_id':np.array([1,2,3,4,5,6]),
  'Product':np.array(['Oven','Oven','Oven','Television','Television','Television'])}

# %%
df1 = pd.DataFrame(d1)

# %%
df1
# Out:
#    Customer_id     Product
# 0            1        Oven
# 1            2        Oven
# 2            3        Oven
# 3            4  Television
# 4            5  Television
# 5            6  Television

# %%
d2 = {'Customer_id':np.array([2,4,6,10]),
    'State':np.array(['California','California','Texas','Boston'])}
df2 = pd.DataFrame(d2)

# %%
df2
# Out:
#    Customer_id       State
# 0            2  California
# 1            4  California
# 2            6       Texas
# 3           10      Boston

# %%
inner_join = pd.merge(df1,df2, on = "Customer_id",how= "inner")

# %%
left_join = pd.merge(df1,df2, on = "Customer_id",how= "left")

# %%
left_join
# Out:
#    Customer_id     Product       State
# 0            1        Oven         NaN
# 1            2        Oven  California
# 2            3        Oven         NaN
# 3            4  Television  California
# 4            5  Television         NaN
# 5            6  Television       Texas

# %%
right_join = pd.merge(df1,df2, on = "Customer_id",how= "right")

# %%
right_join
# Out:
#    Customer_id     Product       State
# 0            2        Oven  California
# 1            4  Television  California
# 2            6  Television       Texas
# 3           10         NaN      Boston

# %%
outer_join = pd.merge(df1,df2, on = "Customer_id",how= "outer")

# %%
outer_join
# Out:
#    Customer_id     Product       State
# 0            1        Oven         NaN
# 1            2        Oven  California
# 2            3        Oven         NaN
# 3            4  Television  California
# 4            5  Television         NaN
# 5            6  Television       Texas
# 6           10         NaN      Boston

# %%
outer_join = outer_join.fillna(0)

# %%
outer_join
# Out:
#    Customer_id     Product       State
# 0            1        Oven           0
# 1            2        Oven  California
# 2            3        Oven           0
# 3            4  Television  California
# 4            5  Television           0
# 5            6  Television       Texas
# 6           10           0      Boston
